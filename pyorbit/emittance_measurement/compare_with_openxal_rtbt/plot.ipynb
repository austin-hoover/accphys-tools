# %%
from matplotlib import pyplot as plt
import proplot as plot
import numpy as np
import pandas as pd

# %%
plt.rcParams['grid.alpha'] = 0.04

# %%
twiss = pd.read_csv('twiss.dat')
twiss
# Out:
#                s       nux       nuy        ax        ay         bx         by
# 0       0.000000  0.000000  0.000000 -0.258970  0.974900   2.299100  14.258300
# 1       0.096400  0.006598  0.001083 -0.303711  0.961713   2.353342  14.071610
# 2       0.192800  0.013034  0.002181 -0.348453  0.948526   2.416211  13.887463
# 3       0.289200  0.019293  0.003293 -0.393194  0.935340   2.487706  13.705859
# 4       0.385600  0.025365  0.004420 -0.437936  0.922153   2.567827  13.526796
# ...          ...       ...       ...       ...       ...        ...        ...
# 1778  170.081350  0.493039  0.364308 -1.376753  0.572950  54.382644   9.645199
# 1779  170.180437  0.493328  0.365953 -1.382029  0.559305  54.656004   9.533007
# 1780  170.279524  0.493616  0.367617 -1.387304  0.545659  54.930409   9.423520
# 1781  170.378611  0.493903  0.369300 -1.392580  0.532014  55.205860   9.316736
# 1782  170.477698  0.494188  0.371002 -1.397855  0.518368  55.482356   9.212657
#
# [1783 rows x 7 columns]

# %%
fig, ax = plot.subplots(figsize=(6, 2))
twiss[['s','bx','by']].plot('s', ax=ax);
